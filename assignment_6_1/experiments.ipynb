# %% [markdown]
# # conduct experiments of the assignment

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# [149.86008199 200.00450933  99.91584662]
# [1.49411765 4.92525253]
# [ 76.50993377 124.39735099]
# [150.4761325]
#
# 1
# my mus = [150.4761325]
# sk mus = [150.4761325]
# my sig = [1667.46147477]
# sk sig = [1667.47147477]
# my aic = 10260.934740345818
# sk aic = 10260.934740363798
# [199.79637922 125.63059469]
#
# 2
# my mus = [200.16747075 126.67797981]
# sk mus = [ 99.80886605 173.62460451]
# my sig = [ 24.69607384 705.29979246]
# sk sig = [ 27.67263618 707.92863315]
# my aic = 9518.53608682871
# sk aic = 9574.886474657418
# [ 99.91584662 149.86008199 200.00450933]
#
# 3
# my mus = [ 99.91584662 149.86008199 200.00450931]
# sk mus = [149.86008199  99.91584662 200.00450931]
# my sig = [29.48290895 25.81095197 26.7896735 ]
# sk sig = [25.82095197 29.49290895 26.7996735 ]
# my aic = 8356.330048247391
# sk aic = 8356.33011582846
# [149.86008199  95.34491578 104.00279655 200.00450933]
#
# 4
# my mus = [149.86008199  83.0790377   99.91584675 200.00450931]
# ...

# %%
# arguments for the em algorithm
emargs = {
    'n': 10,
}

# %%
sel_plt(sample_x, **emargs)
# Out:
# [150.4761325]
# 1 10260.934740345818
# This is the new best model according to aic (above)!
# [100.25448691 174.65692483]
# 2 9575.15542490729
# This is the new best model according to aic (above)!
# [ 99.91584662 149.86008199 200.00450933]
# 3 8356.330048247391
# This is the new best model according to aic (above)!
# [ 99.91584662 153.71664131 145.55398509 200.00450933]
# 4 8362.330046239227
# [104.00279655 195.83543939 149.86008199 203.95415453  95.34491578]
# 5 8368.330035557641
# [104.00279655 149.3909593  142.81160418 155.3647383   95.34491578
#  200.00450933]
# 6 8374.330036889944
# [149.86008199 207.85112807 194.07421087  93.5102939  200.83276261
#  100.53010299 106.78465382]
# 7 8380.33002983934
# [146.35668066 141.37956805  95.34491578 104.00279655 156.00483009
#  203.97795095 195.86042911 150.80423683]
# 8 8386.330038121461
# [ 87.36909733 145.57897068 194.07421087 153.73909997 200.83276261
#  107.4654945   95.62540694 207.85112807 101.60255706]
# 9 8392.330018472738
# ...

# %%
sel_plt(iris_x, **emargs)
# Out:
# [3.75866667]
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# [1.49411765 4.92525253]
# 2 411.07085197276047
# This is the new best model according to aic (above)!
# [4.22857143 5.55686275 1.464     ]
# 3 417.0708499010878
# [1.38918919 1.67692308 4.22857143 5.55686275]
# 4 423.0708478410442
# [5.57391304 4.76585366 3.884      1.464      6.35454545]
# 5 429.0708458522492
# [1.67692308 5.93928571 1.42121212 3.95517241 1.125      4.8744186 ]
# 6 435.0708438477036
# [5.06190476 5.64210526 4.56538462 1.67692308 1.38918919 6.35454545
#  3.84782609]
# 7 441.07084186719953
# [5.04814815 1.63636364 6.6        1.9        1.38918919 5.75909091
#  4.37058824 3.58181818]
# 8 447.07083964537594
# [6.05       5.06190476 1.58518519 4.01764706 4.56538462 3.36666667
#  6.66       5.61176471 1.32173913]
# 9 453.0708381161686
# [4.12142857 3.8        6.66       4.99565217 1.58518519 1.32173913
#  4.545      5.98181818 3.32       5.5375    ]
# 10 459.07083580637993
# ...

# %%
sel_plt(bdp_x, **emargs)
# Out:
# [100.45364238]
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# [ 76.50993377 124.39735099]
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# [124.39735099  73.90990991  83.725     ]
# 3 2187.8788801562146
# This is the new best model according to aic (above)!
# [120.61666667 126.89010989  83.725       73.90990991]
# 4 2188.367410615734
# [ 81.92        71.0212766  124.39735099  76.12121212  87.92307692]
# 5 2201.8320428318075
# [116.6        109.         122.96511628  83.725      128.40740741
#   73.90990991]
# 6 2200.1978554357047
# [ 87.92307692 115.90909091 122.96511628  76.12121212 128.40740741
#   81.92        71.0212766 ]
# 7 2206.1843524477194
# [122.08064516  81.7037037   71.0212766   87.36363636  91.
#  115.6        127.32911392  76.03125   ]
# 8 2212.6209236380887
# [ 81.92        91.         118.53333333  76.12121212 128.40740741
#  112.33333333  71.0212766   87.36363636 123.2278481 ]
# 9 2219.711305561346
# ...
