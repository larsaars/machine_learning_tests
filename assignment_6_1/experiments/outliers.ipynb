# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with vanilla em algorithm

# %%
# arguments for the em algorithm
emargs = {
    'n': 100,
    'init': 'kmeans',
    'check_convergence': True,
    'outliers': 1.5
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [193.3553171]
# sk mus = [193.3553171]
# my sig = [4659.79948027]
# sk sig = [4659.79948127]
# my aic = 1696.6907143927085
# sk aic = 1696.6907143927085
#
# 2
# my mus = [241.7822414  128.50012347]
# sk mus = [152.88771328 279.9352798 ]
# my sig = [1994.68970337  882.08297582]
# sk sig = [1687.62598655   18.95616452]
# my aic = 1676.4563750852146
# sk aic = 1520.9962142146449
#
# 3
# my mus = [126.50152786 279.93389454 199.43567887]
# sk mus = [279.93456978 175.75257034 100.87616417]
# my sig = [664.82003875  19.11621076  19.00339399]
# sk sig = [ 19.11140405 651.23608373  33.39258541]
# my aic = 1432.919766220245
# sk aic = 1460.01850886622
#
# 4
# my mus = [279.93389443 100.94766945 150.26747733 199.38698538]
# sk mus = [279.93389443 100.94766945 199.38698538 150.26747733]
# my sig = [19.11621138 33.76599739 17.93823117 19.26700256]
# sk sig = [19.11621238 33.76599839 19.26700356 17.93823217]
# my aic = 1318.4300352449252
# sk aic = 1318.4300352449252
#
# 5
# my mus = [279.93389443 200.96594377 199.38698538 100.94766945 150.26747733]
# sk mus = [199.38698538 106.12666252 279.93389443 150.26747733  96.61617351]
# my sig = [19.11621138 15.54779599 19.26700256 33.76599739 17.93823117]
# sk sig = [19.26700356  6.22286999 19.11621238 17.93823217 15.60728888]
# my aic = 1324.4300352449252
# sk aic = 1320.8059812990618

# %%
sel_plt(gen_sample_x(5000), show_step_plots, **emargs)
# Out:
# 1 1696.6907143927085
# This is the new best model according to aic (above)!
# 2 1676.4562598029033
# This is the new best model according to aic (above)!
# 3 1432.919766220245
# This is the new best model according to aic (above)!
# 4 1318.4300352449252
# This is the new best model according to aic (above)!
# 5 1324.4300352449252
# 6 1330.4300352449252
# 7 1336.4300352449252
# 8 1342.4300352449252
# 9 1348.4300352449252
# 10 1350.9113495370011
# 11 1360.4300352449252
# 12 1366.7743032945543
# 13 1372.4300352449252
# 14 1378.4300352449252
# 15 1381.4690054539942
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 411.07085197276035
# This is the new best model according to aic (above)!
# 3 417.0708519727604
# 4 423.07085197276047
# 5 430.4942816417282
# 6 435.07085197276047
# 7 441.0708519727604
# 8 447.0708519727606
# 9 453.0708519727608
# 10 459.0708519727604
# 11 465.0708519727604
# 12 471.0708519727604
# 13 477.07085197276047
# 14 483.07085197276206
# 15 489.07085197276047
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# 3 2204.385270471575
# 4 2188.3094136984046
# This is the new best model according to aic (above)!
# 5 2194.7016167705056
# 6 2200.3089528531086
# 7 2205.93884297992
# 8 2212.3279620397107
# 9 2217.9506737264883
# 10 2225.401580209757
# 11 2230.188615287441
# 12 2236.4636543820657
# 13 2242.2070576503056
# 14 2247.9062483959624
# 15 2254.2165351573185
# best model:
