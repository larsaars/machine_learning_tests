# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with em algorithm + more iterations + kmeans init + more data + outlier detection

# %%
# arguments for the em algorithm
emargs = {
    'n': 100,
    'init': 'kmeans',
    'check_convergence': True,
    'outliers': 1.5
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [178.70913175]
# sk mus = [178.70913175]
# my sig = [4347.20059081]
# sk sig = [4347.20059181]
# my aic = 1686.2746661482388
# sk aic = 1686.274666148239
#
# 2
# my mus = [234.21102141 126.53452995]
# sk mus = [233.43396206 125.64535068]
# my sig = [2112.67394153  829.79133214]
# sk sig = [2123.86380116  783.38171563]
# my aic = 1663.5100893662784
# sk aic = 1663.1510054889932
#
# 3
# my mus = [200.25399584 125.68451292 279.33348104]
# sk mus = [100.33224497 279.33465659 172.69620295]
# my sig = [ 19.97452167 674.08326605  15.09804313]
# sk sig = [ 33.75645216  15.09021822 698.19951752]
# my aic = 1463.1420061695012
# sk aic = 1473.868859437049
#
# 4
# my mus = [100.44684703 150.09565551 200.2285095  279.33348081]
# sk mus = [100.44684703 279.33348081 200.2285095  150.09565551]
# my sig = [34.4042208  28.24030555 20.14894934 15.09804455]
# sk sig = [34.4042218  15.09804555 20.14895034 28.24030655]
# my aic = 1338.179994680546
# sk aic = 1338.179994680546
#
# 5
# ...

# %%
sel_plt(gen_sample_x(5000), show_step_plots, **emargs)
# Out:
# 1 56163.5012861881
# This is the new best model according to aic (above)!
# 2 55312.30717671459
# This is the new best model according to aic (above)!
# 3 48873.553165409
# This is the new best model according to aic (above)!
# 4 44190.61815101889
# This is the new best model according to aic (above)!
# 5 44196.61815101889
# 6 44202.61815101889
# 7 44208.61815101889
# 8 44214.61815101889
# 9 44220.61815101889
# 10 44226.61815101889
# 11 44232.61815101889
# 12 44238.61815101889
# 13 44244.61815101889
# 14 44250.61815101889
# 15 44256.61815101889
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 421.77261736895565
# This is the new best model according to aic (above)!
# 3 427.77261737317906
# 4 433.77261732495316
# 5 439.7726173768672
# 6 445.7726173710819
# 7 451.7726173667761
# 8 457.7726173619469
# 9 463.77261736426624
# 10 469.77261736229
# 11 475.7726173670695
# 12 481.7726173715944
# 13 487.7726173740973
# 14 493.7726115083344
# 15 499.77261737441574
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# 3 2204.169283090428
# 4 2188.124815003674
# This is the new best model according to aic (above)!
# 5 2194.126499974438
# 6 2200.534521950043
# 7 2228.1567143523334
# 8 2170.2909608416135
# This is the new best model according to aic (above)!
# 9 2175.653999707775
# 10 2223.680799267483
# 11 2230.314357194009
# 12 2258.158255293602
# 13 2241.6820873839515
# 14 2251.996217682667
# 15 2253.9053585178735
# best model:
