# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with vanilla em algorithm

# %%
# arguments for the em algorithm
emargs = {
    'n': 100,
    'init': 'kmeans',
    'check_convergence': True,
    'outliers': 1.5
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [185.99712146]
# sk mus = [185.99712146]
# my sig = [4255.01635954]
# sk sig = [4255.01636054]
# my aic = 1683.0596428285526
# sk aic = 1683.0596428285523
#
# 2
# my mus = [279.41050307 152.22691657]
# sk mus = [240.26751721 134.01066385]
# my sig = [  31.33847577 1486.91744699]
# sk sig = [2020.802752    871.28698172]
# my aic = 1549.246494505377
# sk aic = 1660.832184798856
#
# 3
# my mus = [171.31562969 101.39624043 279.39310281]
# sk mus = [101.39659947 279.39300443 171.32830283]
# my sig = [671.2850726   17.04468742  31.49687502]
# sk sig = [ 17.05345843  31.49758219 670.40768177]
# my aic = 1481.6102717635713
# sk aic = 1481.588685495335
#
# 4
# my mus = [200.2490406  279.39107479 101.4395424  150.46293408]
# sk mus = [150.46293408 279.39107479 101.4395424  200.2490406 ]
# my sig = [28.53856888 31.51126185 17.37612184 26.88413573]
# sk sig = [26.88413673 31.51126285 17.37612284 28.53856988]
# my aic = 1349.0461072768258
# sk aic = 1349.046107276826
#
# 5
# my mus = [200.2490406  101.4395424  279.39107479 150.46293408 148.42792293]
# sk mus = [202.39521668 101.4395424  279.39107479 150.46293408 194.97052472]
# my sig = [28.53856888 17.37612184 31.51126185 26.88413573 29.03848783]
# sk sig = [17.58600331 17.37612284 31.51126285 26.88413673 16.28503146]
# my aic = 1355.0461072768258
# sk aic = 1355.3891656133908

# %%
sel_plt(gen_sample_x(5000), show_step_plots, **emargs)
# Out:
# 1 56146.22110808186
# This is the new best model according to aic (above)!
# 2 55354.4403567863
# This is the new best model according to aic (above)!
# 3 48671.283541141194
# This is the new best model according to aic (above)!
# 4 48892.913666218235
# 5 44014.68728994169
# This is the new best model according to aic (above)!
# 6 44020.68728994169
# 7 44026.68728994169
# 8 44032.68728994169
# 9 44038.68728994169
# 10 44044.68728994169
# 11 44050.68728994169
# 12 44056.68728994169
# 13 44062.68728994169
# 14 44068.68728994169
# 15 44074.68728994169
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 421.7726173624789
# This is the new best model according to aic (above)!
# 3 427.77261737777087
# 4 433.7726173780567
# 5 439.7726173623172
# 6 445.77261736990965
# 7 451.7726173746263
# 8 457.77261737767884
# 9 463.7726173742451
# 10 469.77261739849666
# 11 475.77261737175536
# 12 481.77261736692446
# 13 487.7726173699015
# 14 493.77261737515664
# 15 499.7726173713149
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# 3 2204.172168791523
# 4 2188.1208676401857
# This is the new best model according to aic (above)!
# 5 2194.5213938682605
# 6 2200.533053993398
# 7 2205.881715089317
# 8 2212.1184882223465
# 9 2224.280409375716
# 10 2227.994164321306
# 11 2230.110756153194
# 12 2193.6607403694907
# 13 2241.6811173900624
# 14 2164.021437960691
# This is the new best model according to aic (above)!
# 15 2254.521401368454
# best model:
