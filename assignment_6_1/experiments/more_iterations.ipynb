# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with vanilla em algorithm

# %%
# arguments for the em algorithm
emargs = {
    'n': 100,
    'init': 'random',
    'check_convergence': True,
    'outliers': 0
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [184.66261714]
# sk mus = [184.66261714]
# my sig = [3984.70665811]
# sk sig = [3984.70665911]
# my aic = 1673.2144065113553
# sk aic = 1673.2144065113553
#
# 2
# my mus = [155.59304434 281.02699666]
# sk mus = [155.5922651  281.02686834]
# my sig = [1532.08543197   27.67520961]
# sk sig = [1532.00192319   27.67664194]
# my aic = 1556.2399659006383
# sk aic = 1556.237849687579
#
# 3
# my mus = [281.02699667 155.5930444  200.55332172]
# sk mus = [200.50236992 132.87089357 280.9929797 ]
# my sig = [  27.67520953 1532.08543874   20.53760239]
# sk sig = [ 21.31365289 723.72219491  27.99162806]
# my aic = 1562.239965900638
# sk aic = 1478.9936345102951
#
# 4
# my mus = [280.9929743   99.25643195 150.55378674 200.23575996]
# sk mus = [280.9929743  150.55378674 200.23575996  99.25643195]
# my sig = [27.9916722  31.16884024 31.83043938 23.85903291]
# sk sig = [27.9916732  31.83044038 23.85903391 31.16884124]
# my aic = 1360.8169740426674
# sk aic = 1360.8169740426677
#
# 5
# my mus = [150.55378674  99.25643195 202.37325521 280.9929743  200.23575996]
# sk mus = [280.9929743  150.55378674 196.13043497  99.25643195 202.51772117]
# my sig = [31.83043938 31.16884024 12.43360817 27.9916722  23.85903291]
# sk sig = [27.9916732  31.83044036 16.44185361 31.16884124 13.40636371]
# my aic = 1366.8169740426674
# sk aic = 1366.7100191505533

# %%
sel_plt(sample_x, show_step_plots, **emargs)
# Out:
# 1 1673.2144065113553
# This is the new best model according to aic (above)!
# 2 1661.4710335795544
# This is the new best model according to aic (above)!
# 3 1558.0532362022714
# This is the new best model according to aic (above)!
# 4 1547.7499806593846
# This is the new best model according to aic (above)!
# 5 1679.470481419558
# 6 1372.8169740426674
# This is the new best model according to aic (above)!
# 7 1378.8169740426674
# 8 1384.8169740426674
# 9 1390.8169740426674
# 10 1394.1688327066195
# 11 1402.8169740426674
# 12 1408.8169740426674
# 13 1414.8169740426674
# 14 1420.8169740426674
# 15 1423.3483683202444
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 605.0248904869825
# 3 417.07085209943057
# This is the new best model according to aic (above)!
# 4 423.0708526301289
# 5 429.07085284882834
# 6 435.07085199578876
# 7 441.07085198487084
# 8 447.0708522552496
# 9 453.07085211917445
# 10 459.0708548661393
# 11 465.07085198993786
# 12 471.07085217278694
# 13 475.51552156288267
# 14 483.07085221070605
# 15 487.5159729467914
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# 3 2204.201912049965
# 4 2215.913194081503
# 5 2151.879014968215
# This is the new best model according to aic (above)!
# 6 2199.6893108896493
# 7 2227.9596753501246
# 8 2212.555989948777
# 9 2176.291796111114
# 10 2245.962421591742
# 11 2229.6923426189906
# 12 2240.2307146017997
# 13 2242.3272892315
# 14 2248.3171888769025
# 15 2254.529954626606
# best model:
