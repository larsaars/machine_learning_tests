# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with em algorithm + more iterations + checking for convergence

# %%
# arguments for the em algorithm
emargs = {
    'n': 100,
    'init': 'random',
    'check_convergence': True,
    'outliers': 0
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [172.31903373]
# sk mus = [172.31903373]
# my sig = [4556.01325054]
# sk sig = [4556.01325154]
# my aic = 1693.3120449014532
# sk aic = 1693.3120449014532
#
# 2
# my mus = [144.24799374 281.61910443]
# sk mus = [144.23471809 281.61522834]
# my sig = [1864.96674783   19.45570482]
# sk sig = [1863.46000133   19.50018275]
# my aic = 1574.69973691857
# sk aic = 1574.6949405637993
#
# 3
# my mus = [119.63085121 281.53557791 200.25284553]
# sk mus = [113.22628231 186.61724861 281.54162703]
# my sig = [638.46336694  20.40931595  25.25700699]
# sk sig = [511.87183937 513.89364726  20.3481064 ]
# my aic = 1484.0388860784096
# sk aic = 1548.6253576908857
#
# 4
# my mus = [200.23161204  99.48453074 281.53557775 149.62689632]
# sk mus = [149.62689632 281.53557775  99.48453074 200.23161204]
# my sig = [25.33921993 24.2609017  20.40931766 17.70051741]
# sk sig = [17.70051841 20.40931866 24.2609027  25.33922093]
# my aic = 1322.112139566949
# sk aic = 1322.1121395669493
#
# 5
# my mus = [149.62689632 200.23161204 202.99812735  99.48453074 281.53557775]
# sk mus = [200.23161204 104.69650482 281.53557775 149.62689632  96.89122365]
# my sig = [17.70051741 25.33921993 22.3787258  24.2609017  20.40931766]
# sk sig = [25.33922093 13.50255881 20.40931866 17.70051841  9.37241017]
# my aic = 1328.112139566949
# sk aic = 1323.6185770672291

# %%
sel_plt(sample_x, show_step_plots, **emargs)
# Out:
# 1 1693.3120449014532
# This is the new best model according to aic (above)!
# 2 1679.9308027085517
# This is the new best model according to aic (above)!
# 3 1455.9974587303536
# This is the new best model according to aic (above)!
# 4 1322.112139566949
# This is the new best model according to aic (above)!
# 5 1328.1121395669493
# 6 1525.419497014982
# 7 1340.112139566949
# 8 1346.112139566949
# 9 1352.112139566949
# 10 1358.112139566949
# 11 1317.019104759399
# This is the new best model according to aic (above)!
# 12 1326.2225923558603
# 13 1327.9344449281596
# 14 1382.112139566949
# 15 1388.112139566949
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 411.0708523124768
# This is the new best model according to aic (above)!
# 3 417.0708520510461
# 4 423.07085273142536
# 5 429.0708540328613
# 6 435.0708520392802
# 7 441.0708519789897
# 8 447.07085203552833
# 9 453.07085201877567
# 10 459.07085230545806
# 11 465.07085289502226
# 12 471.0708521003654
# 13 475.51885850564577
# 14 483.0708520397407
# 15 489.0708521428251
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.91319408151
# This is the new best model according to aic (above)!
# 3 2209.913194081503
# 4 2215.913194081503
# 5 2193.9118509374616
# This is the new best model according to aic (above)!
# 6 2219.266573504086
# 7 2164.2955279729613
# This is the new best model according to aic (above)!
# 8 2234.1944088605637
# 9 2224.279021329735
# 10 2223.9091339252864
# 11 2187.65415375627
# 12 2245.9792493176146
# 13 2199.8786785228826
# 14 2247.9200090486456
# 15 2258.249810873926
# best model:
