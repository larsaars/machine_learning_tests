# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with vanilla em algorithm

# %%
# arguments for the em algorithm
emargs = {
    'n': 10,
    'init': 'random',
    'check_convergence': False,
    'outliers': 0
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [183.2369922]
# sk mus = [183.2369922]
# my sig = [4396.71556558]
# sk sig = [4396.71556658]
# my aic = 1687.9735217808147
# sk aic = 1687.973521780815
#
# 2
# my mus = [279.52160497 149.72575387]
# sk mus = [240.15662451 131.86019913]
# my sig = [  38.48709204 1563.94916978]
# sk sig = [2066.21971094  936.34447557]
# my aic = 1564.2120949501348
# sk aic = 1665.5813854657772
#
# 3
# my mus = [128.91510215 279.4657117  199.68054351]
# sk mus = [ 98.7222359  170.02465738 279.47202196]
# my sig = [696.55720096  39.2114774   19.52989611]
# sk sig = [ 16.13404366 681.71293414  39.13870095]
# my aic = 1495.0422550963524
# sk aic = 1487.4816068407654
#
# 4
# my mus = [199.68807802 149.63588939 279.46570356  98.88075131]
# sk mus = [279.46570356 149.63588939 199.68807802  98.88075131]
# my sig = [20.42794236 22.77813484 39.21157355 17.44032759]
# sk sig = [39.21157455 22.77813584 20.42794336 17.44032859]
# my aic = 1338.6244053555315
# sk aic = 1338.6244053555313
#
# 5
# my mus = [ 98.88075131 149.63588939 199.68807802 279.46570356 144.91062111]
# sk mus = [145.25543485 279.46570356 199.68807802  98.88075131 152.76659494]
# my sig = [17.44032759 22.77813484 20.42794236 39.21157355 27.00184032]
# sk sig = [11.37863285 39.21157455 20.42794336 17.44032859  7.41011618]
# my aic = 1344.6244053555315
# sk aic = 1341.3283638004714

# %%
sel_plt(sample_x, show_step_plots, **emargs)
# Out:
# 1 1687.9735217808147
# This is the new best model according to aic (above)!
# 2 1665.5143221810642
# This is the new best model according to aic (above)!
# 3 1519.5694867270256
# This is the new best model according to aic (above)!
# 4 1576.2120949501352
# 5 1582.2120949501345
# 6 1504.058260344843
# This is the new best model according to aic (above)!
# 7 1356.624405342609
# This is the new best model according to aic (above)!
# 8 1525.042255097961
# 9 1359.0341949695917
# 10 1372.7481445261144
# 11 1380.6244053555315
# 12 1377.034194969715
# 13 1383.0341949696945
# 14 1389.0341949695244
# 15 1395.113940029506
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 411.07085197276035
# This is the new best model according to aic (above)!
# 3 584.7897238755871
# 4 423.0708519727604
# 5 429.07085197276285
# 6 435.07085197276035
# 7 441.07085197276035
# 8 447.07085197288967
# 9 453.0708519727604
# 10 459.07085197276047
# 11 465.0708519727604
# 12 471.07085197276047
# 13 475.7279570832371
# 14 483.07085197276047
# 15 489.07085197276047
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# 3 2209.913193986178
# 4 2198.4921696130655
# This is the new best model according to aic (above)!
# 5 2216.2106959006187
# 6 2205.8772508988013
# 7 2210.3662927257774
# 8 2215.9938686518235
# 9 2240.237837993529
# 10 2245.961257831031
# 11 2230.204753609884
# 12 2236.321112516858
# 13 2242.1881807227337
# 14 1871.0378201565186
# This is the new best model according to aic (above)!
# 15 2254.10226992894
# best model:
