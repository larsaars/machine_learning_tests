# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with vanilla em algorithm

# %%
# arguments for the em algorithm
emargs = {
    'n': 10,
    'init': 'random',
    'check_convergence': False,
    'outliers': 0
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [184.27076213]
# sk mus = [184.27076213]
# my sig = [4272.85649268]
# sk sig = [4272.85649368]
# my aic = 1683.6872375220744
# sk aic = 1683.6872375220744
#
# 2
# my mus = [152.48542443 278.75705362]
# sk mus = [129.1382265  232.04811423]
# my sig = [1688.85855298   23.20808513]
# sk sig = [ 977.00225371 2212.25175164]
# my aic = 1555.0501168428086
# sk aic = 1670.530054193061
#
# 3
# my mus = [127.62447659 278.74815035 199.69115955]
# sk mus = [ 99.76422707 175.56049179 278.74894043]
# my sig = [738.0499036   23.3343231   14.66000899]
# sk sig = [ 27.94361846 616.45091527  23.33089003]
# my aic = 1458.3677395793163
# sk aic = 1477.8127045527078
#
# 4
# my mus = [ 99.86875    151.78428262 199.61476047 278.74814927]
# sk mus = [151.78428262 278.74814927  99.86875    199.61476047]
# my sig = [28.72770585 16.86229759 15.19811051 23.33432755]
# sk sig = [16.86229859 23.33432855 28.72770685 15.19811151]
# my aic = 1314.0279428021295
# sk aic = 1314.0279428021297
#
# 5
# ...

# %%
sel_plt(sample_x, show_step_plots, **emargs)
# Out:
# 1 1683.6872375220744
# This is the new best model according to aic (above)!
# 2 1555.0501168428086
# This is the new best model according to aic (above)!
# 3 1561.0501168428086
# 4 1545.106736415658
# This is the new best model according to aic (above)!
# 5 1470.3655913213984
# This is the new best model according to aic (above)!
# 6 1495.8245496397321
# 7 1332.0279428021295
# This is the new best model according to aic (above)!
# 8 1338.0279428021295
# 9 1344.0279428021295
# 10 1350.0279428021295
# 11 1356.0279428021295
# 12 1362.0279428021295
# 13 1368.0279428021295
# 14 1374.5966628876176
# 15 1380.0279428021295
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 605.0248904869825
# 3 611.0248904869825
# 4 423.07085197276047
# This is the new best model according to aic (above)!
# 5 429.07085197276416
# 6 435.0708519727604
# 7 441.07085197276047
# 8 447.0708519727604
# 9 453.07085197276047
# 10 459.0708519727604
# 11 465.07085197276047
# 12 471.07085197984225
# 13 477.07085197276035
# 14 483.07085197276285
# 15 489.07085197276047
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# 3 2209.909129639772
# 4 2210.424195046855
# 5 2194.0020100306515
# This is the new best model according to aic (above)!
# 6 2200.0439468691034
# 7 2206.6014809008534
# 8 2191.9240362011647
# This is the new best model according to aic (above)!
# 9 2222.4061049807838
# 10 2224.9584663684736
# 11 2229.9056950249396
# 12 2236.6095359552587
# 13 2241.9765485126877
# 14 2208.990370522565
# 15 2255.3423516515186
# best model:
