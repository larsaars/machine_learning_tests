# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with vanilla em algorithm

# %%
# arguments for the em algorithm
emargs = {
    'n': 10,
    'init': 'random',
    'check_convergence': False,
    'outliers': 0
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [181.19150611]
# sk mus = [181.19150611]
# my sig = [3902.77578772]
# sk sig = [3902.77578872]
# my aic = 1670.0980578699928
# sk aic = 1670.0980578699925
#
# 2
# my mus = [223.17315112 128.58190209]
# sk mus = [156.16605202 280.35620506]
# my sig = [2264.48749054  979.40053683]
# sk sig = [1772.77956784   27.72048236]
# my aic = 1664.038811636752
# sk aic = 1578.0013641029345
#
# 3
# my mus = [126.31319254 280.12226573 199.36595652]
# sk mus = [280.1518948  177.68221265 100.27656153]
# my sig = [679.70573473  30.68140422  24.19855423]
# sk sig = [ 30.31887459 660.24663489  27.02909533]
# my aic = 1472.749043260903
# sk aic = 1500.3923178202635
#
# 4
# my mus = [100.50249499 150.23670682 280.12226012 199.35056423]
# sk mus = [199.35056423 100.50249499 280.12226012 150.23670682]
# my sig = [29.24533194 18.29657098 30.68147377 24.55275272]
# sk sig = [24.55275372 29.24533294 30.68147477 18.29657198]
# my aic = 1342.0067875864297
# sk aic = 1342.0067875864297
#
# 5
# my mus = [210.89370001 150.23670682 280.12226012 198.59305495 100.50249499]
# sk mus = [150.23670682 280.12226012 197.60194318 100.50249499 205.47869606]
# my sig = [ 4.70122916 18.29657098 30.68147377 16.53764067 29.24533194]
# sk sig = [18.29657198 30.68147477 12.1740968  29.24533294 19.66460965]
# my aic = 1343.5632655222644
# sk aic = 1344.3322051089272

# %%
sel_plt(sample_x, show_step_plots, **emargs)
# Out:
# 1 1670.0980578699928
# This is the new best model according to aic (above)!
# 2 1663.7615420054906
# This is the new best model according to aic (above)!
# 3 1472.7490432611305
# This is the new best model according to aic (above)!
# 4 1478.7490603779743
# 5 1512.4252657528068
# 6 1487.4374359765345
# 7 1492.878477456844
# 8 1366.0067875864297
# This is the new best model according to aic (above)!
# 9 1327.8258783749193
# This is the new best model according to aic (above)!
# 10 1373.775134916737
# 11 1384.006594366116
# 12 1334.3442571098217
# 13 1391.7670547834987
# 14 1357.8258783749193
# 15 1408.0067875864297
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 411.07085197276047
# This is the new best model according to aic (above)!
# 3 503.69487834486046
# 4 423.07085197276047
# 5 429.07085197276035
# 6 435.07085197276047
# 7 441.0708519727604
# 8 447.0710268984444
# 9 453.07085197276047
# 10 459.07085197276047
# 11 465.0708519727606
# 12 471.0708519727604
# 13 477.07085197276047
# 14 483.07085197276047
# 15 489.0708519727604
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# 3 2204.430993910247
# 4 2167.9240362011647
# This is the new best model according to aic (above)!
# 5 2152.2980128338636
# This is the new best model according to aic (above)!
# 6 2222.2154618356694
# 7 2207.4023412059623
# 8 2233.948882031608
# 9 2113.0768771768235
# This is the new best model according to aic (above)!
# 10 2228.3047941119053
# 11 2187.890875912568
# 12 2236.925094936014
# 13 2246.0300581937254
# 14 2248.323863264817
# 15 2275.947958534932
# best model:
