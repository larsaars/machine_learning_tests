# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with em algorithm + more iterations + check for convergence + kmeans init

# %%
# arguments for the em algorithm
emargs = {
    'n': 100,
    'init': 'kmeans',
    'check_convergence': True,
    'outliers': 0
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [176.39458568]
# sk mus = [176.39458568]
# my sig = [4025.21044861]
# sk sig = [4025.21044961]
# my aic = 1674.7314310397005
# sk aic = 1674.7314310397005
#
# 2
# my mus = [278.38900368 148.93437449]
# sk mus = [148.9343076  278.38899918]
# my sig = [  33.5107324  1545.05424877]
# sk sig = [1545.04651851   33.51082241]
# my aic = 1568.1611284508022
# sk aic = 1568.1598064387256
#
# 3
# my mus = [102.28886667 171.50138038 278.36524239]
# sk mus = [171.48213012 278.36520822 102.28585875]
# my sig = [ 32.81730372 681.19362195  33.66384732]
# sk sig = [682.20100859  33.66404278  32.79907761]
# my aic = 1501.805748615139
# sk aic = 1501.7458033411408
#
# 4
# my mus = [198.94533377 149.80639712 102.44248075 278.36212273]
# sk mus = [278.36212273 102.44248075 198.94533377 149.80639712]
# my sig = [19.52491197 27.81077922 34.04254197 33.68151343]
# sk sig = [33.68151443 34.04254297 19.52491297 27.81078022]
# my aic = 1362.2725705296536
# sk aic = 1362.2725705296539
#
# 5
# my mus = [198.94533377 102.44248075 196.95824141 149.80639712 278.36212273]
# sk mus = [ 96.25592801 198.94533377 278.36212273 149.80639711 106.11008063]
# my sig = [19.52491197 34.04254197 12.48397642 27.81077922 33.68151343]
# sk sig = [11.40394205 19.52491297 33.68151443 27.81078049 11.32238943]
# my aic = 1368.2725705296536
# sk aic = 1364.2794756221936

# %%
sel_plt(sample_x, show_step_plots, **emargs)
# Out:
# 1 1674.7314310397005
# This is the new best model according to aic (above)!
# 2 1568.161131432183
# This is the new best model according to aic (above)!
# 3 1501.8060162741122
# This is the new best model according to aic (above)!
# 4 1362.2725705296539
# This is the new best model according to aic (above)!
# 5 1496.3950618780573
# 6 1374.2725705296539
# 7 1380.2725705296536
# 8 1383.1655293740093
# 9 1392.2725705296539
# 10 1398.2725705296536
# 11 1399.3169224932292
# 12 1406.0905005414259
# 13 1416.2725705296539
# 14 1422.2725705296536
# 15 1424.098474666162
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 411.07085209145566
# This is the new best model according to aic (above)!
# 3 417.07085206008935
# 4 423.0708524660631
# 5 429.0708522015211
# 6 435.0708521885733
# 7 441.0708519824366
# 8 447.07085197543836
# 9 453.07085210164007
# 10 459.070852194729
# 11 465.0708522786098
# 12 471.0708519862118
# 13 477.0708521812397
# 14 483.0708520481496
# 15 487.662099613334
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# 3 2187.885266613059
# This is the new best model according to aic (above)!
# 4 2193.880671401016
# 5 2199.6636553019207
# 6 2222.190977208379
# 7 2205.919253909361
# 8 2211.914002920247
# 9 2239.9602683873723
# 10 2228.003477560245
# 11 2188.2908231555084
# 12 2235.91616741126
# 13 2263.9617471864026
# 14 2260.3466724000114
# 15 2254.153833932496
# best model:
