# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with em algorithm + more iterations + check for convergence + kmeans init

# %%
# arguments for the em algorithm
emargs = {
    'n': 100,
    'init': 'kmeans',
    'check_convergence': True,
    'outliers': 0
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [180.69056565]
# sk mus = [180.69056565]
# my sig = [4546.14854131]
# sk sig = [4546.14854231]
# my aic = 1692.9869118183005
# sk aic = 1692.9869118183003
#
# 2
# my mus = [126.69476604 237.98092475]
# sk mus = [148.1920635  280.58113609]
# my sig = [ 868.6894284  2072.36421921]
# sk sig = [1715.88828801   21.09291804]
# my aic = 1669.0117616116142
# sk aic = 1555.9648017010563
#
# 3
# my mus = [125.53175418 280.56501615 201.24194945]
# sk mus = [280.56652976 173.22202788  99.22706163]
# my sig = [698.97070687  21.21127744  15.73595365]
# sk sig = [ 21.20269807 694.46090518  16.44727922]
# my aic = 1468.1325719170961
# sk aic = 1457.5574221811862
#
# 4
# my mus = [280.56501573  99.24486139 150.28912277 201.19308119]
# sk mus = [ 99.24486139 201.19308119 280.56501573 150.28912277]
# my sig = [21.21127977 16.68958692 22.64142392 16.02282802]
# sk sig = [16.68958792 16.02282902 21.21128077 22.64142492]
# my aic = 1304.9056189644011
# sk aic = 1304.9056189644016
#
# 5
# my mus = [201.19308119 148.18960981 150.28912277  99.24486139 280.56501573]
# sk mus = [ 99.24486139 280.56501573 196.97893477 150.28912277 203.46891098]
# my sig = [16.02282802  9.53502619 22.64142392 16.68958692 21.21127977]
# sk sig = [16.68958792 21.21128077  5.16403844 22.64142492  7.11698617]
# my aic = 1310.9056189644011
# sk aic = 1309.3735985620187

# %%
sel_plt(gen_sample_x(5000), show_step_plots, **emargs)
# Out:
# 1 56188.65499532801
# This is the new best model according to aic (above)!
# 2 55341.16372448269
# This is the new best model according to aic (above)!
# 3 48812.17871502615
# This is the new best model according to aic (above)!
# 4 44227.8053966758
# This is the new best model according to aic (above)!
# 5 44233.80539667627
# 6 44239.8053966758
# 7 44245.8053966758
# 8 44251.805396675794
# 9 44257.80539667581
# 10 44263.8053966758
# 11 44296.13628989333
# 12 44275.8053966758
# 13 44281.8053966758
# 14 44320.81908241115
# 15 44290.94197793138
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 411.07085327812945
# This is the new best model according to aic (above)!
# 3 417.0708521008992
# 4 423.07085201145685
# 5 429.070851980689
# 6 435.07085323900384
# 7 441.0708519852543
# 8 447.07085198116573
# 9 453.07085218161103
# 10 459.0708521546503
# 11 465.0708520334384
# 12 471.0708519746413
# 13 477.0708520761116
# 14 483.07085204395497
# 15 489.07085214169877
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.9131940815037
# This is the new best model according to aic (above)!
# 3 2187.8703228968743
# This is the new best model according to aic (above)!
# 4 2209.9597095763042
# 5 2193.91748968279
# 6 2200.1389842143008
# 7 2212.3007980473135
# 8 2234.195837394829
# 9 2218.143710461488
# 10 2224.1428809803447
# 11 2229.918618625321
# 12 2236.316082111569
# 13 2241.920477354164
# 14 2248.5594699748763
# 15 2212.3007834477244
# best model:
