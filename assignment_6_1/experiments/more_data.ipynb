# %%
import os
os.chdir('..')

# %% [markdown]
# # conduct experiments of the assignment with em algorithm + more iterations + kmeans init + more data

# %%
# arguments for the em algorithm
emargs = {
    'n': 100,
    'init': 'kmeans',
    'check_convergence': True,
    'outliers': 0
}

show_step_plots = False

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [181.27182409]
# sk mus = [181.27182409]
# my sig = [4403.67286874]
# sk sig = [4403.67286974]
# my aic = 1688.2106921509012
# sk aic = 1688.2106921509012
#
# 2
# my mus = [125.61284784 234.62828038]
# sk mus = [125.02040082 234.06276825]
# my sig = [ 792.33216986 2048.94120452]
# sk sig = [ 762.61753248 2064.28797313]
# my aic = 1666.8976508779945
# sk aic = 1666.3628012317554
#
# 3
# my mus = [280.03985431 125.55932354 201.8761844 ]
# sk mus = [125.55484682 280.0398543  201.87598594]
# my sig = [ 17.72911465 675.56312785  20.89901251]
# sk sig = [675.26729764  17.72911573  20.90012827]
# my aic = 1465.1736803161775
# sk aic = 1465.1681810800508
#
# 4
# my mus = [280.03985413  99.80754848 149.95307994 201.8508623 ]
# sk mus = [ 99.80754848 280.03985413 149.95307994 201.8508623 ]
# my sig = [17.72911558 17.15823313 30.57449511 20.98565512]
# sk sig = [17.15823413 17.72911658 30.57449611 20.98565612]
# my aic = 1320.9666955747857
# sk aic = 1320.9666955747862
#
# 5
# my mus = [149.95307994 201.8508623   99.80754848 280.03985413 101.18647493]
# sk mus = [147.84133047 280.03985413 201.8508623   99.80754848 152.98638273]
# my sig = [30.57449511 20.98565512 17.15823313 17.72911558 17.19402935]
# sk sig = [28.05095929 17.72911658 20.98565612 17.15823413 18.59278609]
# my aic = 1326.9666955747857
# sk aic = 1326.8494308704642

# %%
sel_plt(gen_sample_x(5000), show_step_plots, **emargs)
# Out:
# 1 56144.9003179972
# This is the new best model according to aic (above)!
# 2 55348.688232740664
# This is the new best model according to aic (above)!
# 3 48611.077134749445
# This is the new best model according to aic (above)!
# 4 44221.81177404715
# This is the new best model according to aic (above)!
# 5 44227.81177404715
# 6 44233.82670556077
# 7 44239.81177404714
# 8 44245.81177404715
# 9 44251.81177404715
# 10 44257.81177404715
# 11 44263.81177404715
# 12 44269.81177404714
# 13 44275.81177404715
# 14 44283.25335701422
# 15 44335.737624978356
# best model:

# %%
sel_plt(iris_x, show_step_plots, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 411.07085202338135
# This is the new best model according to aic (above)!
# 3 417.0708543870485
# 4 423.0708521499647
# 5 429.07085228904606
# 6 435.07085200846007
# 7 441.07085197789036
# 8 447.07085231512275
# 9 453.0708520437665
# 10 459.07085205075526
# 11 465.0708523199711
# 12 471.0708521006134
# 13 477.0708520750601
# 14 483.0708519865283
# 15 489.07085197390745
# best model:

# %%
sel_plt(bdp_x, show_step_plots, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2203.913194081503
# This is the new best model according to aic (above)!
# 3 2187.8701013736973
# This is the new best model according to aic (above)!
# 4 2188.1577469879785
# 5 2194.152641960914
# 6 2199.914039691536
# 7 2205.936410390564
# 8 2212.5672282430996
# 9 2217.916776726349
# 10 2224.5560512695088
# 11 2230.559128063872
# 12 2194.2907435267625
# 13 2242.1370943229276
# 14 2252.0077965517653
# 15 2253.693848157818
# best model:
