# %% [markdown]
# # conduct experiments of the assignment with vanilla em algorithm

# %%
# arguments for the em algorithm
emargs = {
    'n': 10,
    'init': 'random',
}

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [151.94642891]
# sk mus = [151.94642891]
# my sig = [1704.42670362]
# sk sig = [1704.43670362]
# my aic = 10282.86115537132
# sk aic = 10282.861155388531
#
# 2
# my mus = [125.88773537 199.84257767]
# sk mus = [176.13667854 100.24671673]
# my sig = [693.72842216  19.9484903 ]
# sk sig = [655.75503536  22.20345032]
# my aic = 9388.440039639772
# sk aic = 9467.006820554816
#
# 3
# my mus = [199.77437212 100.36119397 150.66093346]
# sk mus = [150.66093346 100.36119397 199.77437212]
# my sig = [20.53448698 23.35251638 24.77510273]
# sk sig = [24.78510273 23.36251638 20.54448698]
# my aic = 8171.810603730768
# sk aic = 8171.810701733277
#
# 4
# my mus = [148.31618788 199.77437212 100.36119397 150.66093347]
# sk mus = [103.30453889 199.77437212 150.66093346  96.37140575]
# my sig = [22.54374368 20.53448698 23.35251638 24.77510272]
# sk sig = [12.32075323 20.54448698 24.7851028  10.66820913]
# my aic = 8177.810601730673
# sk aic = 8175.368834553275
#
# 5
# my mus = [150.66093346 103.51529721 201.98911651 100.36119396 199.77437212]
# sk mus = [199.77437212 103.16288713 146.52763574  96.26226689 153.30181902]
# my sig = [24.77510273 25.71120721 19.29953235 23.35251634 20.53448697]
# sk sig = [20.54448698 12.78734789 13.37458424 10.54903744 14.18577598]
# my aic = 8183.810599727577
# sk aic = 8183.043419917378

# %%
sel_plt(sample_x, **emargs)
# Out:
# 1 10282.86115537132
# This is the new best model according to aic (above)!
# 2 9965.564654008895
# This is the new best model according to aic (above)!
# 3 8346.649911341563
# This is the new best model according to aic (above)!
# 4 8254.813860154249
# This is the new best model according to aic (above)!
# 5 8916.910895879764
# 6 8213.287384046065
# This is the new best model according to aic (above)!
# 7 8264.630197685754
# 8 8223.577532848218
# 9 8238.940559230745
# 10 8232.088973659165
# 11 8354.699364277789
# 12 8349.664211113492
# 13 8240.155612402377
# 14 8296.127068533078
# 15 8260.396072767851
# best model:

# %%
sel_plt(iris_x, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 592.0057496299999
# This is the new best model according to aic (above)!
# 3 572.1683582110327
# This is the new best model according to aic (above)!
# 4 502.9294553271982
# This is the new best model according to aic (above)!
# 5 499.73316625725175
# This is the new best model according to aic (above)!
# 6 562.2637919335899
# 7 568.2199174585335
# 8 590.197806964786
# 9 523.9071725212514
# 10 554.7022016455602
# 11 484.0061489859563
# This is the new best model according to aic (above)!
# 12 573.9466538700716
# 13 590.0441493505951
# 14 563.7725095190697
# 15 502.83401416997197
# best model:

# %%
sel_plt(bdp_x, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2204.1346556829108
# This is the new best model according to aic (above)!
# 3 2458.954675916811
# 4 2218.4684100842996
# 5 2212.6580122584405
# 6 2222.705339534656
# 7 2226.7693526802536
# 8 2236.351418781206
# 9 2235.898433078114
# 10 2237.2751519574035
# 11 2252.298243024242
# 12 2251.8724930806625
# 13 2257.9074635897778
# 14 2256.9038672508023
# 15 2274.891548505816
# best model:
