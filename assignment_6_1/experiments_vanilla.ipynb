# %% [markdown]
# # conduct experiments of the assignment with vanilla em algorithm

# %%
# arguments for the em algorithm
emargs = {
    'n': 10,
    'init': 'random',
    'outliers': 3
}

# %%
# import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [151.29557166]
# sk mus = [151.29557166]
# my sig = [1732.4946922]
# sk sig = [1732.5046922]
# my aic = 10299.194733801543
# sk aic = 10299.194733818202
#
# 2
# my mus = [125.77707791 200.58467076]
# sk mus = [200.58459421 125.77612228]
# my sig = [707.63462377  24.81821431]
# sk sig = [ 24.83247797 707.58297654]
# my aic = 9495.560390483904
# sk aic = 9495.403690203735
#
# 3
# my mus = [150.31155088  99.78167497 200.47465529]
# sk mus = [150.31155088 200.47465529  99.78167497]
# my sig = [25.22896563 25.13416479 25.844345  ]
# sk sig = [25.23896563 25.854345   25.14416479]
# my aic = 8285.292455775994
# sk aic = 8285.292533197064
#
# 4
# my mus = [103.28781598 200.47465529  99.78167495 150.31155088]
# sk mus = [196.49791715  99.78167497 150.31155088 203.5499776 ]
# my sig = [22.0871765  25.844345   25.13416476 25.22896563]
# sk sig = [13.43108123 25.14416479 25.23896563 13.7742419 ]
# my aic = 8291.292453770498
# sk aic = 8291.405250590884
#
# 5
# my mus = [200.47465529  99.78167496 102.61139635 150.31155089 145.99470506]
# sk mus = [153.43312618  99.78167497 203.47935162 146.26296738 196.55276458]
# my sig = [25.844345   25.13416476 23.97531503 25.22896557 25.52431612]
# sk sig = [11.37154882 25.14416479 14.21436039 14.19557582 13.8821595 ]
# my aic = 8297.292451752162
# sk aic = 8290.13748479114

# %%
sel_plt(sample_x, **emargs)
# Out:
# 1 10299.194733801543
# This is the new best model according to aic (above)!
# 2 9520.285631431849
# This is the new best model according to aic (above)!
# 3 9501.560388517482
# This is the new best model according to aic (above)!
# 4 8291.29245374062
# This is the new best model according to aic (above)!
# 5 8297.292451775049
# 6 8303.292449460148
# 7 8309.292447626853
# 8 8315.292446469313
# 9 8321.292442640144
# 10 8327.292440967827
# 11 8333.29243866998
# 12 8339.292437363903
# 13 8345.919792189681
# 14 8351.292433334282
# 15 8357.292429122639
# best model:

# %%
sel_plt(iris_x, **emargs)
# Out:
# 1 599.0248904869825
# This is the new best model according to aic (above)!
# 2 421.77262377387365
# This is the new best model according to aic (above)!
# 3 427.7726217628645
# 4 433.77261966050713
# 5 439.7726175311761
# 6 445.7726152477354
# 7 451.77261326534995
# 8 457.7726110443414
# 9 463.7725770258844
# 10 469.77260742992985
# 11 475.77260289017624
# 12 481.7726014484624
# 13 487.77256880388154
# 14 493.7725994685285
# 15 499.77259670903527
# best model:

# %%
sel_plt(bdp_x, **emargs)
# Out:
# 1 2790.4060160663075
# This is the new best model according to aic (above)!
# 2 2796.4060057410843
# 3 2194.1600513836893
# This is the new best model according to aic (above)!
# 4 2193.643225352111
# This is the new best model according to aic (above)!
# 5 2221.8941472258707
# 6 2183.7078238948643
# This is the new best model according to aic (above)!
# 7 2214.8190908951024
# 8 2198.5728109557012
# 9 2230.159638312585
# 10 2224.3217339358234
# 11 2230.3163696730953
# 12 2230.208283095988
# 13 2241.8991551994377
# 14 2247.8997286659524
# 15 2244.113075567686
# best model:
