# %%
import os
os.chdir('..')

# %% [markdown]
# # How does the experiment perform when using log likelihood instead of AIC?

# %%
 # arguments for the em algorithm
emargs = {
    'n': 100,
    'init': 'kmeans',
    'check_convergence': True,
    'outliers': 0 
}

# %%
 # import em implementation etc.
# %run em.ipynb
# Out:
# 1
# my mus = [180.20308448]
# sk mus = [180.20308448]
# my sig = [4556.72244393]
# sk sig = [4556.72244493]
# my aic = 1693.335392228229
# sk aic = 1693.335392228229
#
# 2
# my mus = [124.61103073 236.63784685]
# sk mus = [147.60979875 280.35081019]
# my sig = [ 759.24921794 2089.55404618]
# sk sig = [1706.83242605   19.72366125]
# my aic = 1666.4784334601554
# sk aic = 1552.9996238898043
#
# 3
# my mus = [201.09883751 280.33427233 125.31206381]
# sk mus = [173.62724373 100.47499503 280.33612516]
# my sig = [ 17.01859397  19.84781363 695.69569218]
# sk sig = [699.7249941   18.6607977   19.83616459]
# my aic = 1468.1163724463404
# sk aic = 1455.2781836722465
#
# 4
# my mus = [100.50246296 150.23127211 200.84427327 280.3342719 ]
# sk mus = [280.3342719  100.50246296 200.84427327 150.23127211]
# my sig = [18.81259626 34.32713451 19.56814442 19.84781635]
# sk sig = [19.84781735 18.81259726 19.56814542 34.32713551]
# my aic = 1329.255593463879
# sk aic = 1329.2555934638792
#
# 5
# ...

# %%
sel_plt(gen_sample_x(5000), show_step_plots=False, use_aic=False, greater=True, **emargs)
# Out:
# 1 -28086.063563780284
# This is the new best model according to aic (above)!
# 2 -27667.955150062193
# This is the new best model according to aic (above)!
# 3 -24391.02786485215
# This is the new best model according to aic (above)!
# 4 -22026.138431639763
# This is the new best model according to aic (above)!
# 5 -22026.138431639763
# 6 -22026.138431639763
# 7 -22026.13843163976
# This is the new best model according to aic (above)!
# 8 -22038.919649354135
# 9 -22026.138431639763
# 10 -22026.138431639763
# 11 -22026.138431639763
# 12 -22026.138431639763
# 13 -22026.138431639763
# 14 -22026.138431639763
# 15 -22026.138431639763
# best model:
