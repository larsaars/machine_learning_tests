# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from skimage import color
from skimage import io
from hilbert_flatten import *

import sys
sys.path.append('../conv_pool')

from conv import *
from img_utils import *

# %%
# read list of the 64 64*64 images
imgs = []
for i in range(1, 65):
    imgs.append(read_im(f'./data/mov/{i}.bmp'))
     
imgs = np.array(imgs)
imgs.shape
# Out:
# (64, 64, 64)

# %%
reshaped = hilbert_remap(imgs, out_dim=2, byte_size=16)
print(reshaped.shape)
plt_im(reshaped)
# Out:
# (512, 512)
