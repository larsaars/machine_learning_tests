# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from skimage import color
from skimage import io
from hilbert_flatten import *

import sys
sys.path.append('../conv_pool')

from conv import *
from img_utils import *

# %%
# size is 1024*1024 pixels
img = read_im('./data/biarritz1024.jpg')
# flatten the image with hilbert curve
flat = hilbert_flatten(img, 16)
print(flat)
plt_im(img) # expand(flat, 2, 16))
print(img.shape)
# Out:
# [0.71144196 0.7069549  0.71087647 ... 0.36552627 0.34591843 0.4870949 ]
# (1024, 1024)

# %%
X = pool1(flat, 
               k=12, 
               s=13, 
               action=np.max)

dim = 2





#pooled = augment_array(pooled, 2)

# plt_im(expanded)
# Out:
# 80659
# next fit: 262144
